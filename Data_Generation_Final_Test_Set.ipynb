# %%
import os
import random
import shutil
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import albumentations as A
from tqdm.auto import tqdm
import cv2 # Потрібен для preprocess_for_classifier

# ---------------------------------
# 1. КОНФІГУРАЦІЯ
# ---------------------------------
print("--- Етап 1: Конфігурація 'Золотого' Тест-сету ---")

# --- Налаштування ---
BASE_DIR = 'learning'
VALID_FONT_DIR = os.path.join(BASE_DIR, 'fonts_valid') # Використовуємо валідаційні шрифти

# Створюємо 2500 * 2 (чисті + аугментовані) = 5000 зображень
NUM_BASE_IMAGES = 2500

# --- Параметри генерації ---
SCENE_SIZE = (640, 640)
FONT_SIZES = [40, 50, 60, 70, 80]
MAX_DIGITS_IN_NUMBER = 5

# --- Нові шляхи ---
FINAL_TEST_DIR = os.path.join(BASE_DIR, 'final_test_set')
IMG_DIR = os.path.join(FINAL_TEST_DIR, 'images')
LBL_DIR = os.path.join(FINAL_TEST_DIR, 'labels') # Тут будуть .txt з ЧИСЛАМИ

# ---------------------------------
# 2. ОЧИЩЕННЯ ТА СТВОРЕННЯ
# ---------------------------------
if os.path.exists(FINAL_TEST_DIR):
    print(f"Очищую стару директорію: {FINAL_TEST_DIR}...")
    shutil.rmtree(FINAL_TEST_DIR)

print("Створення нових директорій...")
os.makedirs(IMG_DIR, exist_ok=True)
os.makedirs(LBL_DIR, exist_ok=True)

# ---------------------------------
# 3. ДОПОМІЖНІ ФУНКЦІЇ (з "Мега-генератора")
# ---------------------------------

def get_font_files(directory):
    try:
        files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.ttf')]
        if not files:
            raise FileNotFoundError(f"Директорія {directory} порожня.")
        return files
    except FileNotFoundError as e:
        print(f"Помилка: {e}")
        return []

def create_number_block(number_str, font_path, font_size):
    try:
        font = ImageFont.truetype(font_path, font_size)
    except IOError:
        font = ImageFont.load_default()

    bboxes = []
    images = []
    current_x = 0

    for char in number_str:
        bbox = font.getbbox(char)
        char_width = bbox[2] - bbox[0]
        char_height = bbox[3] - bbox[1]
        char_img = Image.new('L', (char_width + 4, font_size + 10), 0)
        draw = ImageDraw.Draw(char_img)
        draw.text((2 - bbox[0], 5 - bbox[1]), char, font=font, fill=255)

        # Нам потрібні bboxes лише для трансформації
        x_min = current_x + 2
        y_min = 5
        x_max = x_min + char_width
        y_max = y_min + char_height
        bboxes.append([int(char), x_min, y_min, x_max, y_max]) # [class, x1, y1, x2, y2]

        images.append(char_img)
        current_x += char_img.width + random.randint(-5, 2)

    total_width = current_x
    block_height = font_size + 10
    if total_width <= 0 or block_height <= 0:
        return None, None

    block_img = Image.new('L', (total_width, block_height), 0)
    current_x = 0
    for img in images:
        block_img.paste(img, (current_x, 0))
        current_x += img.width + random.randint(-5, 2)

    return np.array(block_img), bboxes

def get_transforms(is_augmented=False):
    if not is_augmented:
        block_transform = A.NoOp()
        scene_transform = A.NoOp()
    else:
        block_transform = A.Compose([
            A.Perspective(scale=(0.02, 0.08), pad_mode=0, p=0.7),
            A.ShiftScaleRotate(shift_limit=0.1, scale_limit=(-0.2, 0.2), rotate_limit=10, p=0.8),
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['class_labels']))

        scene_transform = A.Compose([
            A.GaussNoise(var_limit=(10.0, 50.0), p=0.5),
            A.MotionBlur(blur_limit=(3, 15), p=0.5),
            A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.6),
            A.Blur(blur_limit=(3, 5), p=0.3),
        ])
    return block_transform, scene_transform

# ---------------------------------
# 4. ГОЛОВНИЙ ЦИКЛ ГЕНЕРАЦІЇ
# ---------------------------------
print("--- Етап 2: Запуск генерації тест-сету ---")

try:
    valid_fonts = get_font_files(VALID_FONT_DIR)

    pbar = tqdm(total=NUM_BASE_IMAGES, desc="Генерація тест-сету")

    for i in range(NUM_BASE_IMAGES):

        # 1. Генеруємо "правильну" відповідь
        number_len = random.randint(1, MAX_DIGITS_IN_NUMBER)
        number_str = "".join([str(random.randint(0, 9)) for _ in range(number_len)])
        font_path = random.choice(valid_fonts)
        font_size = random.choice(FONT_SIZES)

        base_img_name = f"img_{i:05d}" # 00001, 00002...

        # 2. Генеруємо ОБИДВІ версії (чисту та аугментовану)
        versions_to_generate = [
            {"is_augmented": False, "suffix": "clean"},
            {"is_augmented": True, "suffix": "aug"}
        ]

        for config in versions_to_generate:
            is_augmented = config["is_augmented"]
            suffix = config["suffix"]

            # --- Генерація сцени ---
            scene_img = None
            while scene_img is None: # Повторюємо, якщо генерація не вдалася
                scene_bg = np.random.randint(0, 40, SCENE_SIZE, dtype=np.uint8)
                block_img, bboxes = create_number_block(number_str, font_path, font_size)
                if block_img is None: continue

                block_transform, scene_transform = get_transforms(is_augmented)
                class_labels = [b[0] for b in bboxes]
                pascal_bboxes = [b[1:] for b in bboxes]

                try:
                    transformed = block_transform(image=block_img, bboxes=pascal_bboxes, class_labels=class_labels)
                    transformed_img = transformed['image']
                except Exception:
                    continue # Помилка аугментації

                t_h, t_w = transformed_img.shape
                max_x = SCENE_SIZE[0] - t_w
                max_y = SCENE_SIZE[1] - t_h
                if max_x <= 0 or max_y <= 0: continue # Блок завеликий

                paste_x = random.randint(0, max_x)
                paste_y = random.randint(0, max_y)

                mask = (transformed_img > 0).astype(np.uint8)
                scene_bg[paste_y:paste_y+t_h, paste_x:paste_x+t_w] = np.where(
                    mask > 0, transformed_img, scene_bg[paste_y:paste_y+t_h, paste_x:paste_x+t_w])

                scene_img = scene_transform(image=scene_bg)['image']

            # --- ЗБЕРІГАЄМО ---
            current_img_name = f"{base_img_name}_{suffix}.png"
            current_lbl_name = f"{base_img_name}_{suffix}.txt"

            # 1. Зберігаємо зображення
            img_path = os.path.join(IMG_DIR, current_img_name)
            Image.fromarray(scene_img).save(img_path)

            # 2. Зберігаємо "чисту" мітку (ПРОСТО ЧИСЛО)
            lbl_path = os.path.join(LBL_DIR, current_lbl_name)
            with open(lbl_path, 'w') as f:
                f.write(number_str)

        pbar.update(1)

    pbar.close()
    print(f"\n--- ✅ Створено {NUM_BASE_IMAGES * 2} тестових зразків у {FINAL_TEST_DIR} ---")

except Exception as e:
    print(f"\n\n--- ❌ ПОМИЛКА ПІД ЧАС ВИКОНАННЯ ---")
    print(e)
# Out:
# --- Етап 1: Конфігурація 'Золотого' Тест-сету ---
# Створення нових директорій...
# --- Етап 2: Запуск генерації тест-сету ---
# Генерація Тесту (x2):  44%|█████████████████████████▎                               | 1108/2500 [05:15<06:36,  3.51it/s]
# /tmp/ipykernel_363054/3095340766.py:104: UserWarning: Argument(s) 'pad_mode' are not valid for transform Perspective
#   A.Perspective(scale=(0.02, 0.08), pad_mode=0, p=0.7),
# /home/yesman/tfvenv/lib/python3.12/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /tmp/ipykernel_363054/3095340766.py:109: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 50.0), p=0.5),
#
# Генерація тест-сету:   0%|                                                             | 1/2500 [00:00<04:33,  9.12it/s]
# Генерація тест-сету:   0%|                                                             | 3/2500 [00:00<02:58, 14.02it/s]
# Генерація тест-сету:   0%|                                                             | 5/2500 [00:00<03:11, 13.02it/s]
# Генерація тест-сету:   0%|▏                                                            | 7/2500 [00:00<03:43, 11.14it/s]
# Генерація тест-сету:   0%|▏                                                            | 9/2500 [00:00<03:45, 11.06it/s]
# Генерація тест-сету:   0%|▎                                                           | 11/2500 [00:00<03:31, 11.75it/s]
# Генерація тест-сету:   1%|▎                                                           | 13/2500 [00:01<03:18, 12.51it/s]
# Генерація тест-сету:   1%|▎                                                           | 15/2500 [00:01<03:23, 12.22it/s]
# Генерація тест-сету:   1%|▍                                                           | 17/2500 [00:01<03:40, 11.26it/s]
# Генерація тест-сету:   1%|▍                                                           | 19/2500 [00:01<03:36, 11.46it/s]
# Генерація тест-сету:   1%|▌                                                           | 21/2500 [00:01<03:25, 12.04it/s]
# Генерація тест-сету:   1%|▌                                                           | 23/2500 [00:01<03:30, 11.77it/s]
# Генерація тест-сету:   1%|▌                                                           | 25/2500 [00:02<03:45, 10.97it/s]
# Генерація тест-сету:   1%|▋                                                           | 27/2500 [00:02<03:55, 10.50it/s]
# Генерація тест-сету:   1%|▋                                                           | 29/2500 [00:02<03:55, 10.51it/s]
# Генерація тест-сету:   1%|▋                                                           | 31/2500 [00:02<03:46, 10.92it/s]
# Генерація тест-сету:   1%|▊                                                           | 33/2500 [00:02<03:39, 11.23it/s]
# Генерація тест-сету:   1%|▊                                                           | 35/2500 [00:03<03:37, 11.31it/s]
# Генерація тест-сету:   1%|▉                                                           | 37/2500 [00:03<03:37, 11.34it/s]
# Генерація тест-сету:   2%|▉                                                           | 39/2500 [00:03<03:24, 12.01it/s]
# Генерація тест-сету:   2%|▉                                                           | 41/2500 [00:03<03:17, 12.47it/s]
# Генерація тест-сету:   2%|█                                                           | 43/2500 [00:03<03:11, 12.83it/s]
# Генерація тест-сету:   2%|█                                                           | 45/2500 [00:03<03:20, 12.22it/s]
# Генерація тест-сету:   2%|█▏                                                          | 47/2500 [00:04<03:35, 11.40it/s]
# Генерація тест-сету:   2%|█▏                                                          | 49/2500 [00:04<03:23, 12.03it/s]
# Генерація тест-сету:   2%|█▏                                                          | 51/2500 [00:04<03:32, 11.50it/s]
# Генерація тест-сету:   2%|█▎                                                          | 53/2500 [00:04<03:44, 10.92it/s]
# Генерація тест-сету:   2%|█▎                                                          | 55/2500 [00:04<03:24, 11.97it/s]
# Генерація тест-сету:   2%|█▎                                                          | 57/2500 [00:04<03:14, 12.59it/s]
# Генерація тест-сету:   2%|█▍                                                          | 59/2500 [00:05<03:29, 11.65it/s]
# Генерація тест-сету:   2%|█▍                                                          | 61/2500 [00:05<03:29, 11.64it/s]
# Генерація тест-сету:   3%|█▌                                                          | 63/2500 [00:05<03:30, 11.57it/s]
# Генерація тест-сету:   3%|█▌                                                          | 65/2500 [00:05<03:47, 10.69it/s]
# Генерація тест-сету:   3%|█▌                                                          | 67/2500 [00:05<03:20, 12.12it/s]
# Генерація тест-сету:   3%|█▋                                                          | 69/2500 [00:05<03:19, 12.16it/s]
# Генерація тест-сету:   3%|█▋                                                          | 71/2500 [00:06<03:28, 11.67it/s]
# Генерація тест-сету:   3%|█▊                                                          | 73/2500 [00:06<03:30, 11.52it/s]
# Генерація тест-сету:   3%|█▊                                                          | 75/2500 [00:06<03:35, 11.27it/s]
# Генерація тест-сету:   3%|█▊                                                          | 77/2500 [00:06<03:27, 11.67it/s]
# Генерація тест-сету:   3%|█▉                                                          | 79/2500 [00:06<03:21, 12.03it/s]
# Генерація тест-сету:   3%|█▉                                                          | 81/2500 [00:06<03:28, 11.61it/s]
# Генерація тест-сету:   3%|█▉                                                          | 83/2500 [00:07<03:15, 12.37it/s]
# Генерація тест-сету:   3%|██                                                          | 85/2500 [00:07<03:03, 13.13it/s]
# Генерація тест-сету:   3%|██                                                          | 87/2500 [00:07<03:01, 13.29it/s]
# Генерація тест-сету:   4%|██▏                                                         | 89/2500 [00:07<03:05, 12.97it/s]
# Генерація тест-сету:   4%|██▏                                                         | 91/2500 [00:07<03:11, 12.59it/s]
# Генерація тест-сету:   4%|██▏                                                         | 93/2500 [00:07<03:13, 12.41it/s]
# Генерація тест-сету:   4%|██▎                                                         | 95/2500 [00:08<03:11, 12.54it/s]
# Генерація тест-сету:   4%|██▎                                                         | 97/2500 [00:08<03:18, 12.13it/s]
# Генерація тест-сету:   4%|██▍                                                         | 99/2500 [00:08<03:21, 11.89it/s]
# Генерація тест-сету:   4%|██▍                                                        | 101/2500 [00:08<03:37, 11.02it/s]
# Генерація тест-сету:   4%|██▍                                                        | 103/2500 [00:08<03:33, 11.23it/s]
# Генерація тест-сету:   4%|██▍                                                        | 105/2500 [00:08<03:36, 11.08it/s]
# Генерація тест-сету:   4%|██▌                                                        | 107/2500 [00:09<03:25, 11.65it/s]
# Генерація тест-сету:   4%|██▌                                                        | 109/2500 [00:09<03:34, 11.13it/s]
# Генерація тест-сету:   4%|██▌                                                        | 111/2500 [00:09<03:21, 11.84it/s]
# Генерація тест-сету:   5%|██▋                                                        | 113/2500 [00:09<03:18, 12.05it/s]
# Генерація тест-сету:   5%|██▋                                                        | 115/2500 [00:09<03:24, 11.67it/s]
# Генерація тест-сету:   5%|██▊                                                        | 117/2500 [00:09<03:30, 11.35it/s]
# Генерація тест-сету:   5%|██▊                                                        | 119/2500 [00:10<03:32, 11.19it/s]
# Генерація тест-сету:   5%|██▊                                                        | 121/2500 [00:10<03:20, 11.84it/s]
# Генерація тест-сету:   5%|██▉                                                        | 123/2500 [00:10<03:31, 11.26it/s]
# Генерація тест-сету:   5%|██▉                                                        | 125/2500 [00:10<03:45, 10.54it/s]
# Генерація тест-сету:   5%|██▉                                                        | 127/2500 [00:10<03:43, 10.62it/s]
# Генерація тест-сету:   5%|███                                                        | 129/2500 [00:11<03:46, 10.46it/s]
# Генерація тест-сету:   5%|███                                                        | 131/2500 [00:11<03:40, 10.73it/s]
# Генерація тест-сету:   5%|███▏                                                       | 133/2500 [00:11<03:45, 10.49it/s]
# Генерація тест-сету:   5%|███▏                                                       | 135/2500 [00:11<03:39, 10.79it/s]
# Генерація тест-сету:   5%|███▏                                                       | 137/2500 [00:11<03:48, 10.32it/s]
# Генерація тест-сету:   6%|███▎                                                       | 139/2500 [00:12<03:36, 10.89it/s]
# Генерація тест-сету:   6%|███▎                                                       | 141/2500 [00:12<03:36, 10.90it/s]
# Генерація тест-сету:   6%|███▎                                                       | 143/2500 [00:12<03:37, 10.84it/s]
# Генерація тест-сету:   6%|███▍                                                       | 145/2500 [00:12<03:22, 11.66it/s]
# Генерація тест-сету:   6%|███▍                                                       | 147/2500 [00:12<03:29, 11.22it/s]
# Генерація тест-сету:   6%|███▌                                                       | 149/2500 [00:12<03:32, 11.08it/s]
# Генерація тест-сету:   6%|███▌                                                       | 151/2500 [00:13<03:13, 12.15it/s]
# Генерація тест-сету:   6%|███▌                                                       | 153/2500 [00:13<02:58, 13.15it/s]
# Генерація тест-сету:   6%|███▋                                                       | 155/2500 [00:13<03:06, 12.57it/s]
# Генерація тест-сету:   6%|███▋                                                       | 157/2500 [00:13<03:03, 12.75it/s]
# Генерація тест-сету:   6%|███▊                                                       | 159/2500 [00:13<03:17, 11.88it/s]
# Генерація тест-сету:   6%|███▊                                                       | 161/2500 [00:13<03:12, 12.13it/s]
# Генерація тест-сету:   7%|███▊                                                       | 163/2500 [00:14<03:24, 11.40it/s]
# Генерація тест-сету:   7%|███▉                                                       | 165/2500 [00:14<03:25, 11.39it/s]
# Генерація тест-сету:   7%|███▉                                                       | 167/2500 [00:14<03:38, 10.67it/s]
# Генерація тест-сету:   7%|███▉                                                       | 169/2500 [00:14<03:39, 10.64it/s]
# Генерація тест-сету:   7%|████                                                       | 171/2500 [00:14<03:37, 10.73it/s]
# Генерація тест-сету:   7%|████                                                       | 173/2500 [00:15<03:36, 10.75it/s]
# Генерація тест-сету:   7%|████▏                                                      | 175/2500 [00:15<03:34, 10.82it/s]
# Генерація тест-сету:   7%|████▏                                                      | 177/2500 [00:15<03:23, 11.40it/s]
# Генерація тест-сету:   7%|████▏                                                      | 179/2500 [00:15<03:33, 10.88it/s]
# Генерація тест-сету:   7%|████▎                                                      | 181/2500 [00:15<03:41, 10.45it/s]
# Генерація тест-сету:   7%|████▎                                                      | 183/2500 [00:15<03:29, 11.07it/s]
# Генерація тест-сету:   7%|████▎                                                      | 185/2500 [00:16<03:32, 10.87it/s]
# Генерація тест-сету:   7%|████▍                                                      | 187/2500 [00:16<03:50, 10.04it/s]
# Генерація тест-сету:   8%|████▍                                                      | 189/2500 [00:16<03:38, 10.55it/s]
# Генерація тест-сету:   8%|████▌                                                      | 191/2500 [00:16<03:20, 11.51it/s]
# Генерація тест-сету:   8%|████▌                                                      | 193/2500 [00:16<03:28, 11.04it/s]
# Генерація тест-сету:   8%|████▌                                                      | 195/2500 [00:17<03:31, 10.92it/s]
# Генерація тест-сету:   8%|████▋                                                      | 197/2500 [00:17<03:37, 10.59it/s]
# Генерація тест-сету:   8%|████▋                                                      | 199/2500 [00:17<03:34, 10.74it/s]
# Генерація тест-сету:   8%|████▋                                                      | 201/2500 [00:17<03:23, 11.32it/s]
# Генерація тест-сету:   8%|████▊                                                      | 203/2500 [00:17<03:28, 11.04it/s]
# Генерація тест-сету:   8%|████▊                                                      | 205/2500 [00:17<03:37, 10.54it/s]
# Генерація тест-сету:   8%|████▉                                                      | 207/2500 [00:18<03:25, 11.14it/s]
# Генерація тест-сету:   8%|████▉                                                      | 209/2500 [00:18<03:32, 10.79it/s]
# Генерація тест-сету:   8%|████▉                                                      | 211/2500 [00:18<03:21, 11.34it/s]
# Генерація тест-сету:   9%|█████                                                      | 213/2500 [00:18<03:24, 11.18it/s]
# Генерація тест-сету:   9%|█████                                                      | 215/2500 [00:18<03:08, 12.10it/s]
# Генерація тест-сету:   9%|█████                                                      | 217/2500 [00:19<03:31, 10.80it/s]
# Генерація тест-сету:   9%|█████▏                                                     | 219/2500 [00:19<03:26, 11.07it/s]
# Генерація тест-сету:   9%|█████▏                                                     | 221/2500 [00:19<03:34, 10.64it/s]
# Генерація тест-сету:   9%|█████▎                                                     | 223/2500 [00:19<03:33, 10.65it/s]
# Генерація тест-сету:   9%|█████▎                                                     | 225/2500 [00:21<11:30,  3.29it/s]
# Генерація тест-сету:   9%|█████▎                                                     | 227/2500 [00:21<08:51,  4.28it/s]
# Генерація тест-сету:   9%|█████▍                                                     | 229/2500 [00:21<07:06,  5.32it/s]
# Генерація тест-сету:   9%|█████▍                                                     | 231/2500 [00:21<06:05,  6.21it/s]
# Генерація тест-сету:   9%|█████▍                                                     | 233/2500 [00:21<05:22,  7.04it/s]
# Генерація тест-сету:   9%|█████▌                                                     | 235/2500 [00:22<04:55,  7.65it/s]
# Генерація тест-сету:   9%|█████▌                                                     | 237/2500 [00:22<04:13,  8.92it/s]
# Генерація тест-сету:  10%|█████▋                                                     | 239/2500 [00:22<03:54,  9.63it/s]
# Генерація тест-сету:  10%|█████▋                                                     | 241/2500 [00:22<03:40, 10.23it/s]
# Генерація тест-сету:  10%|█████▋                                                     | 243/2500 [00:22<03:25, 10.96it/s]
# Генерація тест-сету:  10%|█████▊                                                     | 245/2500 [00:22<03:22, 11.14it/s]
# Генерація тест-сету:  10%|█████▊                                                     | 247/2500 [00:23<03:17, 11.43it/s]
# Генерація тест-сету:  10%|█████▉                                                     | 249/2500 [00:23<03:13, 11.63it/s]
# Генерація тест-сету:  10%|█████▉                                                     | 251/2500 [00:23<03:11, 11.75it/s]
# Генерація тест-сету:  10%|█████▉                                                     | 253/2500 [00:23<03:03, 12.21it/s]
# Генерація тест-сету:  10%|██████                                                     | 255/2500 [00:23<03:05, 12.07it/s]
# Генерація тест-сету:  10%|██████                                                     | 257/2500 [00:23<03:08, 11.89it/s]
# Генерація тест-сету:  10%|██████                                                     | 259/2500 [00:24<03:11, 11.71it/s]
# Генерація тест-сету:  10%|██████▏                                                    | 261/2500 [00:24<02:57, 12.65it/s]
# Генерація тест-сету:  11%|██████▏                                                    | 263/2500 [00:24<03:01, 12.30it/s]
# Генерація тест-сету:  11%|██████▎                                                    | 265/2500 [00:24<03:18, 11.24it/s]
# Генерація тест-сету:  11%|██████▎                                                    | 267/2500 [00:24<03:31, 10.54it/s]
# Генерація тест-сету:  11%|██████▎                                                    | 269/2500 [00:24<03:27, 10.76it/s]
# Генерація тест-сету:  11%|██████▍                                                    | 271/2500 [00:25<03:24, 10.91it/s]
# Генерація тест-сету:  11%|██████▍                                                    | 273/2500 [00:25<03:17, 11.30it/s]
# Генерація тест-сету:  11%|██████▍                                                    | 275/2500 [00:25<03:21, 11.03it/s]
# Генерація тест-сету:  11%|██████▌                                                    | 277/2500 [00:25<03:24, 10.89it/s]
# Генерація тест-сету:  11%|██████▌                                                    | 279/2500 [00:25<03:05, 11.95it/s]
# Генерація тест-сету:  11%|██████▋                                                    | 281/2500 [00:25<02:59, 12.34it/s]
# Генерація тест-сету:  11%|██████▋                                                    | 283/2500 [00:26<03:09, 11.70it/s]
# Генерація тест-сету:  11%|██████▋                                                    | 285/2500 [00:26<03:12, 11.48it/s]
# Генерація тест-сету:  11%|██████▊                                                    | 287/2500 [00:26<02:57, 12.50it/s]
# Генерація тест-сету:  12%|██████▊                                                    | 289/2500 [00:26<03:00, 12.25it/s]
# Генерація тест-сету:  12%|██████▊                                                    | 291/2500 [00:26<03:02, 12.12it/s]
# Генерація тест-сету:  12%|██████▉                                                    | 293/2500 [00:26<03:00, 12.24it/s]
# Генерація тест-сету:  12%|██████▉                                                    | 295/2500 [00:27<03:12, 11.46it/s]
# Генерація тест-сету:  12%|███████                                                    | 297/2500 [00:27<03:18, 11.12it/s]
# Генерація тест-сету:  12%|███████                                                    | 299/2500 [00:27<03:18, 11.09it/s]
# Генерація тест-сету:  12%|███████                                                    | 301/2500 [00:27<03:07, 11.70it/s]
# Генерація тест-сету:  12%|███████▏                                                   | 303/2500 [00:27<03:07, 11.69it/s]
# Генерація тест-сету:  12%|███████▏                                                   | 305/2500 [00:28<03:14, 11.29it/s]
# Генерація тест-сету:  12%|███████▏                                                   | 307/2500 [00:28<03:03, 11.96it/s]
# Генерація тест-сету:  12%|███████▎                                                   | 309/2500 [00:28<03:01, 12.04it/s]
# Генерація тест-сету:  12%|███████▎                                                   | 311/2500 [00:28<03:17, 11.07it/s]
# Генерація тест-сету:  13%|███████▍                                                   | 313/2500 [00:28<03:19, 10.98it/s]
# Генерація тест-сету:  13%|███████▍                                                   | 315/2500 [00:28<03:02, 11.96it/s]
# Генерація тест-сету:  13%|███████▍                                                   | 317/2500 [00:29<03:10, 11.47it/s]
# Генерація тест-сету:  13%|███████▌                                                   | 319/2500 [00:29<03:09, 11.53it/s]
# Генерація тест-сету:  13%|███████▌                                                   | 321/2500 [00:29<03:06, 11.65it/s]
# Генерація тест-сету:  13%|███████▌                                                   | 323/2500 [00:29<03:27, 10.48it/s]
# Генерація тест-сету:  13%|███████▋                                                   | 325/2500 [00:29<03:34, 10.15it/s]
# Генерація тест-сету:  13%|███████▋                                                   | 327/2500 [00:30<03:47,  9.54it/s]
# Генерація тест-сету:  13%|███████▊                                                   | 329/2500 [00:30<03:30, 10.34it/s]
# Генерація тест-сету:  13%|███████▊                                                   | 331/2500 [00:30<03:21, 10.78it/s]
# Генерація тест-сету:  13%|███████▊                                                   | 333/2500 [00:30<03:36, 10.03it/s]
# Генерація тест-сету:  13%|███████▉                                                   | 335/2500 [00:30<03:19, 10.87it/s]
# Генерація тест-сету:  13%|███████▉                                                   | 337/2500 [00:30<03:14, 11.14it/s]
# Генерація тест-сету:  14%|████████                                                   | 339/2500 [00:31<03:14, 11.11it/s]
# Генерація тест-сету:  14%|████████                                                   | 341/2500 [00:31<03:27, 10.42it/s]
# Генерація тест-сету:  14%|████████                                                   | 343/2500 [00:31<03:11, 11.28it/s]
# Генерація тест-сету:  14%|████████▏                                                  | 345/2500 [00:31<03:25, 10.46it/s]
# Генерація тест-сету:  14%|████████▏                                                  | 347/2500 [00:31<03:18, 10.84it/s]
# Генерація тест-сету:  14%|████████▏                                                  | 349/2500 [00:32<03:02, 11.80it/s]
# Генерація тест-сету:  14%|████████▎                                                  | 351/2500 [00:32<02:58, 12.06it/s]
# Генерація тест-сету:  14%|████████▎                                                  | 353/2500 [00:32<02:57, 12.09it/s]
# Генерація тест-сету:  14%|████████▍                                                  | 355/2500 [00:32<03:08, 11.37it/s]
# Генерація тест-сету:  14%|████████▍                                                  | 357/2500 [00:32<03:20, 10.68it/s]
# Генерація тест-сету:  14%|████████▍                                                  | 359/2500 [00:32<03:12, 11.14it/s]
# Генерація тест-сету:  14%|████████▌                                                  | 361/2500 [00:33<03:17, 10.85it/s]
# Генерація тест-сету:  15%|████████▌                                                  | 363/2500 [00:33<03:20, 10.68it/s]
# Генерація тест-сету:  15%|████████▌                                                  | 365/2500 [00:33<03:33, 10.02it/s]
# Генерація тест-сету:  15%|████████▋                                                  | 367/2500 [00:33<03:12, 11.07it/s]
# Генерація тест-сету:  15%|████████▋                                                  | 369/2500 [00:33<03:10, 11.19it/s]
# Генерація тест-сету:  15%|████████▊                                                  | 371/2500 [00:34<03:24, 10.42it/s]
# Генерація тест-сету:  15%|████████▊                                                  | 373/2500 [00:34<03:28, 10.20it/s]
# Генерація тест-сету:  15%|████████▊                                                  | 375/2500 [00:34<03:19, 10.64it/s]
# Генерація тест-сету:  15%|████████▉                                                  | 377/2500 [00:34<03:08, 11.27it/s]
# Генерація тест-сету:  15%|████████▉                                                  | 379/2500 [00:34<03:05, 11.42it/s]
# Генерація тест-сету:  15%|████████▉                                                  | 381/2500 [00:34<03:06, 11.37it/s]
# Генерація тест-сету:  15%|█████████                                                  | 383/2500 [00:35<02:59, 11.77it/s]
# Генерація тест-сету:  15%|█████████                                                  | 385/2500 [00:35<02:42, 12.98it/s]
# Генерація тест-сету:  15%|█████████▏                                                 | 387/2500 [00:35<02:37, 13.42it/s]
# Генерація тест-сету:  16%|█████████▏                                                 | 389/2500 [00:35<02:52, 12.23it/s]
# Генерація тест-сету:  16%|█████████▏                                                 | 391/2500 [00:35<02:53, 12.13it/s]
# Генерація тест-сету:  16%|█████████▎                                                 | 393/2500 [00:35<02:58, 11.81it/s]
# Генерація тест-сету:  16%|█████████▎                                                 | 395/2500 [00:36<02:52, 12.17it/s]
# Генерація тест-сету:  16%|█████████▎                                                 | 397/2500 [00:36<02:47, 12.57it/s]
# Генерація тест-сету:  16%|█████████▍                                                 | 399/2500 [00:36<02:48, 12.44it/s]
# Генерація тест-сету:  16%|█████████▍                                                 | 401/2500 [00:36<02:59, 11.68it/s]
# Генерація тест-сету:  16%|█████████▌                                                 | 403/2500 [00:36<03:05, 11.32it/s]
# Генерація тест-сету:  16%|█████████▌                                                 | 405/2500 [00:36<03:07, 11.18it/s]
# Генерація тест-сету:  16%|█████████▌                                                 | 407/2500 [00:37<03:03, 11.40it/s]
# Генерація тест-сету:  16%|█████████▋                                                 | 409/2500 [00:37<03:06, 11.21it/s]
# Генерація тест-сету:  16%|█████████▋                                                 | 411/2500 [00:37<03:05, 11.26it/s]
# Генерація тест-сету:  17%|█████████▋                                                 | 413/2500 [00:37<03:26, 10.11it/s]
# Генерація тест-сету:  17%|█████████▊                                                 | 415/2500 [00:37<03:19, 10.47it/s]
# Генерація тест-сету:  17%|█████████▊                                                 | 417/2500 [00:38<03:07, 11.10it/s]
# Генерація тест-сету:  17%|█████████▉                                                 | 419/2500 [00:38<03:04, 11.30it/s]
# Генерація тест-сету:  17%|█████████▉                                                 | 421/2500 [00:38<02:56, 11.77it/s]
# Генерація тест-сету:  17%|█████████▉                                                 | 423/2500 [00:38<02:56, 11.80it/s]
# Генерація тест-сету:  17%|██████████                                                 | 425/2500 [00:38<03:14, 10.70it/s]
# Генерація тест-сету:  17%|██████████                                                 | 427/2500 [00:38<03:23, 10.17it/s]
# Генерація тест-сету:  17%|██████████                                                 | 429/2500 [00:39<03:14, 10.65it/s]
# Генерація тест-сету:  17%|██████████▏                                                | 431/2500 [00:39<03:11, 10.80it/s]
# Генерація тест-сету:  17%|██████████▏                                                | 433/2500 [00:39<03:12, 10.74it/s]
# Генерація тест-сету:  17%|██████████▎                                                | 435/2500 [00:39<03:13, 10.66it/s]
# Генерація тест-сету:  17%|██████████▎                                                | 437/2500 [00:39<03:12, 10.69it/s]
# Генерація тест-сету:  18%|██████████▎                                                | 439/2500 [00:40<03:08, 10.93it/s]
# Генерація тест-сету:  18%|██████████▍                                                | 441/2500 [00:40<03:20, 10.29it/s]
# Генерація тест-сету:  18%|██████████▍                                                | 443/2500 [00:40<03:29,  9.81it/s]
# Генерація тест-сету:  18%|██████████▌                                                | 445/2500 [00:40<03:12, 10.65it/s]
# Генерація тест-сету:  18%|██████████▌                                                | 447/2500 [00:40<03:12, 10.67it/s]
# Генерація тест-сету:  18%|██████████▌                                                | 449/2500 [00:41<03:12, 10.67it/s]
# Генерація тест-сету:  18%|██████████▋                                                | 451/2500 [00:41<03:27,  9.87it/s]
# Генерація тест-сету:  18%|██████████▋                                                | 453/2500 [00:41<03:22, 10.10it/s]
# Генерація тест-сету:  18%|██████████▋                                                | 455/2500 [00:41<03:16, 10.40it/s]
# Генерація тест-сету:  18%|██████████▊                                                | 457/2500 [00:41<03:09, 10.78it/s]
# Генерація тест-сету:  18%|██████████▊                                                | 459/2500 [00:41<02:57, 11.48it/s]
# Генерація тест-сету:  18%|██████████▉                                                | 461/2500 [00:42<03:09, 10.78it/s]
# Генерація тест-сету:  19%|██████████▉                                                | 463/2500 [00:42<02:59, 11.34it/s]
# Генерація тест-сету:  19%|██████████▉                                                | 465/2500 [00:42<02:53, 11.73it/s]
# Генерація тест-сету:  19%|███████████                                                | 467/2500 [00:42<03:04, 10.99it/s]
# Генерація тест-сету:  19%|███████████                                                | 469/2500 [00:42<02:42, 12.51it/s]
# Генерація тест-сету:  19%|███████████                                                | 471/2500 [00:42<02:47, 12.08it/s]
# Генерація тест-сету:  19%|███████████▏                                               | 473/2500 [00:43<02:49, 11.94it/s]
# Генерація тест-сету:  19%|███████████▏                                               | 475/2500 [00:43<02:51, 11.82it/s]
# Генерація тест-сету:  19%|███████████▎                                               | 477/2500 [00:43<03:01, 11.13it/s]
# Генерація тест-сету:  19%|███████████▎                                               | 479/2500 [00:43<03:06, 10.82it/s]
# Генерація тест-сету:  19%|███████████▎                                               | 481/2500 [00:43<03:05, 10.88it/s]
# Генерація тест-сету:  19%|███████████▍                                               | 483/2500 [00:44<03:05, 10.87it/s]
# Генерація тест-сету:  19%|███████████▍                                               | 485/2500 [00:44<03:31,  9.54it/s]
# Генерація тест-сету:  19%|███████████▍                                               | 486/2500 [00:44<03:32,  9.46it/s]
# Генерація тест-сету:  20%|███████████▌                                               | 488/2500 [00:44<03:11, 10.49it/s]
# Генерація тест-сету:  20%|███████████▌                                               | 490/2500 [00:44<03:12, 10.46it/s]
# Генерація тест-сету:  20%|███████████▌                                               | 492/2500 [00:44<03:05, 10.81it/s]
# Генерація тест-сету:  20%|███████████▋                                               | 494/2500 [00:45<03:03, 10.95it/s]
# Генерація тест-сету:  20%|███████████▋                                               | 496/2500 [00:45<03:02, 11.00it/s]
# Генерація тест-сету:  20%|███████████▊                                               | 498/2500 [00:45<02:55, 11.38it/s]
# Генерація тест-сету:  20%|███████████▊                                               | 500/2500 [00:45<03:06, 10.71it/s]
# Генерація тест-сету:  20%|███████████▊                                               | 502/2500 [00:45<03:11, 10.42it/s]
# Генерація тест-сету:  20%|███████████▉                                               | 504/2500 [00:46<03:01, 10.97it/s]
# Генерація тест-сету:  20%|███████████▉                                               | 506/2500 [00:46<03:19,  9.99it/s]
# Генерація тест-сету:  20%|███████████▉                                               | 508/2500 [00:46<03:05, 10.71it/s]
# Генерація тест-сету:  20%|████████████                                               | 510/2500 [00:46<03:11, 10.40it/s]
# Генерація тест-сету:  20%|████████████                                               | 512/2500 [00:46<03:01, 10.97it/s]
# Генерація тест-сету:  21%|████████████▏                                              | 514/2500 [00:47<02:52, 11.49it/s]
# Генерація тест-сету:  21%|████████████▏                                              | 516/2500 [00:47<02:59, 11.08it/s]
# Генерація тест-сету:  21%|████████████▏                                              | 518/2500 [00:47<02:54, 11.33it/s]
# Генерація тест-сету:  21%|████████████▎                                              | 520/2500 [00:47<02:56, 11.20it/s]
# Генерація тест-сету:  21%|████████████▎                                              | 522/2500 [00:47<03:02, 10.84it/s]
# Генерація тест-сету:  21%|████████████▎                                              | 524/2500 [00:47<02:52, 11.45it/s]
# Генерація тест-сету:  21%|████████████▍                                              | 526/2500 [00:48<02:47, 11.76it/s]
# Генерація тест-сету:  21%|████████████▍                                              | 528/2500 [00:48<02:49, 11.66it/s]
# Генерація тест-сету:  21%|████████████▌                                              | 530/2500 [00:48<02:44, 12.00it/s]
# Генерація тест-сету:  21%|████████████▌                                              | 532/2500 [00:48<02:49, 11.62it/s]
# Генерація тест-сету:  21%|████████████▌                                              | 534/2500 [00:48<03:04, 10.63it/s]
# Генерація тест-сету:  21%|████████████▋                                              | 536/2500 [00:48<02:51, 11.48it/s]
# Генерація тест-сету:  22%|████████████▋                                              | 538/2500 [00:49<02:50, 11.51it/s]
# Генерація тест-сету:  22%|████████████▋                                              | 540/2500 [00:49<02:47, 11.71it/s]
# Генерація тест-сету:  22%|████████████▊                                              | 542/2500 [00:49<03:01, 10.81it/s]
# Генерація тест-сету:  22%|████████████▊                                              | 544/2500 [00:49<02:55, 11.11it/s]
# Генерація тест-сету:  22%|████████████▉                                              | 546/2500 [00:49<02:56, 11.08it/s]
# Генерація тест-сету:  22%|████████████▉                                              | 548/2500 [00:50<02:59, 10.89it/s]
# Генерація тест-сету:  22%|████████████▉                                              | 550/2500 [00:50<03:04, 10.56it/s]
# Генерація тест-сету:  22%|█████████████                                              | 552/2500 [00:50<03:05, 10.53it/s]
# Генерація тест-сету:  22%|█████████████                                              | 554/2500 [00:50<02:59, 10.85it/s]
# Генерація тест-сету:  22%|█████████████                                              | 556/2500 [00:50<02:57, 10.94it/s]
# Генерація тест-сету:  22%|█████████████▏                                             | 558/2500 [00:50<02:50, 11.39it/s]
# Генерація тест-сету:  22%|█████████████▏                                             | 560/2500 [00:51<03:02, 10.63it/s]
# Генерація тест-сету:  22%|█████████████▎                                             | 562/2500 [00:51<03:00, 10.71it/s]
# Генерація тест-сету:  23%|█████████████▎                                             | 564/2500 [00:51<02:54, 11.08it/s]
# Генерація тест-сету:  23%|█████████████▎                                             | 566/2500 [00:51<02:54, 11.08it/s]
# Генерація тест-сету:  23%|█████████████▍                                             | 568/2500 [00:51<03:13,  9.96it/s]
# Генерація тест-сету:  23%|█████████████▍                                             | 570/2500 [00:52<03:09, 10.18it/s]
# Генерація тест-сету:  23%|█████████████▍                                             | 572/2500 [00:52<03:19,  9.67it/s]
# Генерація тест-сету:  23%|█████████████▌                                             | 574/2500 [00:52<03:04, 10.44it/s]
# Генерація тест-сету:  23%|█████████████▌                                             | 576/2500 [00:52<03:02, 10.56it/s]
# Генерація тест-сету:  23%|█████████████▋                                             | 578/2500 [00:52<03:08, 10.19it/s]
# Генерація тест-сету:  23%|█████████████▋                                             | 580/2500 [00:53<03:10, 10.10it/s]
# Генерація тест-сету:  23%|█████████████▋                                             | 582/2500 [00:53<03:08, 10.16it/s]
# Генерація тест-сету:  23%|█████████████▊                                             | 584/2500 [00:55<10:21,  3.08it/s]
# Генерація тест-сету:  23%|█████████████▊                                             | 586/2500 [00:55<07:57,  4.01it/s]
# Генерація тест-сету:  24%|█████████████▉                                             | 588/2500 [00:55<06:30,  4.90it/s]
# Генерація тест-сету:  24%|█████████████▉                                             | 589/2500 [00:55<06:01,  5.28it/s]
# Генерація тест-сету:  24%|█████████████▉                                             | 590/2500 [00:56<08:25,  3.78it/s]
# Генерація тест-сету:  24%|█████████████▉                                             | 591/2500 [00:56<07:33,  4.21it/s]
# Генерація тест-сету:  24%|█████████████▉                                             | 592/2500 [00:56<06:35,  4.83it/s]
# Генерація тест-сету:  24%|█████████████▉                                             | 593/2500 [00:56<06:03,  5.24it/s]
# Генерація тест-сету:  24%|██████████████                                             | 595/2500 [00:56<04:38,  6.85it/s]
# Генерація тест-сету:  24%|██████████████                                             | 596/2500 [00:56<04:28,  7.10it/s]
# Генерація тест-сету:  24%|██████████████                                             | 598/2500 [00:56<03:45,  8.43it/s]
# Генерація тест-сету:  24%|██████████████▏                                            | 600/2500 [00:57<03:05, 10.27it/s]
# Генерація тест-сету:  24%|██████████████▏                                            | 602/2500 [00:57<03:05, 10.22it/s]
# Генерація тест-сету:  24%|██████████████▎                                            | 604/2500 [00:57<03:56,  8.03it/s]
# Генерація тест-сету:  24%|██████████████▎                                            | 605/2500 [00:57<03:57,  7.99it/s]
# Генерація тест-сету:  24%|██████████████▎                                            | 606/2500 [00:57<03:48,  8.28it/s]
# Генерація тест-сету:  24%|██████████████▎                                            | 607/2500 [00:57<03:40,  8.60it/s]
# Генерація тест-сету:  24%|██████████████▎                                            | 609/2500 [00:58<03:24,  9.25it/s]
# Генерація тест-сету:  24%|██████████████▍                                            | 611/2500 [00:58<03:17,  9.55it/s]
# Генерація тест-сету:  25%|██████████████▍                                            | 613/2500 [00:58<03:16,  9.61it/s]
# Генерація тест-сету:  25%|██████████████▍                                            | 614/2500 [00:58<03:35,  8.75it/s]
# Генерація тест-сету:  25%|██████████████▌                                            | 615/2500 [00:58<03:35,  8.76it/s]
# Генерація тест-сету:  25%|██████████████▌                                            | 616/2500 [00:58<03:42,  8.48it/s]
# Генерація тест-сету:  25%|██████████████▌                                            | 618/2500 [00:59<03:15,  9.64it/s]
# Генерація тест-сету:  25%|██████████████▋                                            | 620/2500 [00:59<03:08,  9.95it/s]
# Генерація тест-сету:  25%|██████████████▋                                            | 622/2500 [00:59<03:07,  9.99it/s]
# Генерація тест-сету:  25%|██████████████▋                                            | 624/2500 [00:59<03:06, 10.07it/s]
# Генерація тест-сету:  25%|██████████████▊                                            | 626/2500 [00:59<02:58, 10.49it/s]
# Генерація тест-сету:  25%|██████████████▊                                            | 628/2500 [00:59<02:48, 11.13it/s]
# Генерація тест-сету:  25%|██████████████▊                                            | 630/2500 [01:00<02:58, 10.47it/s]
# Генерація тест-сету:  25%|██████████████▉                                            | 632/2500 [01:00<02:52, 10.80it/s]
# Генерація тест-сету:  25%|██████████████▉                                            | 634/2500 [01:00<02:54, 10.71it/s]
# Генерація тест-сету:  25%|███████████████                                            | 636/2500 [01:00<02:45, 11.28it/s]
# Генерація тест-сету:  26%|███████████████                                            | 638/2500 [01:00<02:50, 10.92it/s]
# Генерація тест-сету:  26%|███████████████                                            | 640/2500 [01:01<03:05, 10.05it/s]
# Генерація тест-сету:  26%|███████████████▏                                           | 642/2500 [01:01<03:08,  9.84it/s]
# Генерація тест-сету:  26%|███████████████▏                                           | 644/2500 [01:01<03:07,  9.91it/s]
# Генерація тест-сету:  26%|███████████████▏                                           | 646/2500 [01:01<03:19,  9.28it/s]
# Генерація тест-сету:  26%|███████████████▎                                           | 647/2500 [01:01<03:32,  8.74it/s]
# Генерація тест-сету:  26%|███████████████▎                                           | 648/2500 [01:02<03:34,  8.64it/s]
# Генерація тест-сету:  26%|███████████████▎                                           | 650/2500 [01:02<03:11,  9.65it/s]
# Генерація тест-сету:  26%|███████████████▎                                           | 651/2500 [01:02<03:14,  9.52it/s]
# Генерація тест-сету:  26%|███████████████▍                                           | 652/2500 [01:02<03:14,  9.51it/s]
# Генерація тест-сету:  26%|███████████████▍                                           | 654/2500 [01:02<02:58, 10.36it/s]
# Генерація тест-сету:  26%|███████████████▍                                           | 656/2500 [01:02<02:51, 10.77it/s]
# Генерація тест-сету:  26%|███████████████▌                                           | 658/2500 [01:02<02:41, 11.39it/s]
# Генерація тест-сету:  26%|███████████████▌                                           | 660/2500 [01:03<02:54, 10.57it/s]
# Генерація тест-сету:  26%|███████████████▌                                           | 662/2500 [01:03<03:03, 10.02it/s]
# Генерація тест-сету:  27%|███████████████▋                                           | 664/2500 [01:03<02:55, 10.46it/s]
# Генерація тест-сету:  27%|███████████████▋                                           | 666/2500 [01:03<03:00, 10.18it/s]
# Генерація тест-сету:  27%|███████████████▊                                           | 668/2500 [01:03<02:50, 10.77it/s]
# Генерація тест-сету:  27%|███████████████▊                                           | 670/2500 [01:04<03:01, 10.10it/s]
# Генерація тест-сету:  27%|███████████████▊                                           | 672/2500 [01:04<03:04,  9.91it/s]
# Генерація тест-сету:  27%|███████████████▉                                           | 674/2500 [01:04<02:59, 10.16it/s]
# Генерація тест-сету:  27%|███████████████▉                                           | 676/2500 [01:04<02:51, 10.64it/s]
# Генерація тест-сету:  27%|████████████████                                           | 678/2500 [01:04<02:39, 11.42it/s]
# Генерація тест-сету:  27%|████████████████                                           | 680/2500 [01:05<02:41, 11.27it/s]
# Генерація тест-сету:  27%|████████████████                                           | 682/2500 [01:05<02:50, 10.67it/s]
# Генерація тест-сету:  27%|████████████████▏                                          | 684/2500 [01:05<02:53, 10.46it/s]
# Генерація тест-сету:  27%|████████████████▏                                          | 686/2500 [01:05<02:48, 10.77it/s]
# Генерація тест-сету:  28%|████████████████▏                                          | 688/2500 [01:05<02:45, 10.92it/s]
# Генерація тест-сету:  28%|████████████████▎                                          | 690/2500 [01:05<02:39, 11.34it/s]
# Генерація тест-сету:  28%|████████████████▎                                          | 692/2500 [01:06<02:41, 11.20it/s]
# Генерація тест-сету:  28%|████████████████▍                                          | 694/2500 [01:06<02:46, 10.86it/s]
# Генерація тест-сету:  28%|████████████████▍                                          | 696/2500 [01:06<02:46, 10.83it/s]
# Генерація тест-сету:  28%|████████████████▍                                          | 698/2500 [01:06<02:43, 11.02it/s]
# Генерація тест-сету:  28%|████████████████▌                                          | 700/2500 [01:06<02:39, 11.28it/s]
# Генерація тест-сету:  28%|████████████████▌                                          | 702/2500 [01:07<02:31, 11.90it/s]
# Генерація тест-сету:  28%|████████████████▌                                          | 704/2500 [01:07<02:28, 12.10it/s]
# Генерація тест-сету:  28%|████████████████▋                                          | 706/2500 [01:07<02:26, 12.23it/s]
# Генерація тест-сету:  28%|████████████████▋                                          | 708/2500 [01:07<02:30, 11.88it/s]
# Генерація тест-сету:  28%|████████████████▊                                          | 710/2500 [01:07<02:30, 11.87it/s]
# Генерація тест-сету:  28%|████████████████▊                                          | 712/2500 [01:07<02:31, 11.78it/s]
# Генерація тест-сету:  29%|████████████████▊                                          | 714/2500 [01:08<02:33, 11.64it/s]
# Генерація тест-сету:  29%|████████████████▉                                          | 716/2500 [01:08<02:36, 11.41it/s]
# Генерація тест-сету:  29%|████████████████▉                                          | 718/2500 [01:08<02:37, 11.29it/s]
# Генерація тест-сету:  29%|████████████████▉                                          | 720/2500 [01:08<02:46, 10.70it/s]
# Генерація тест-сету:  29%|█████████████████                                          | 722/2500 [01:08<02:45, 10.77it/s]
# Генерація тест-сету:  29%|█████████████████                                          | 724/2500 [01:08<02:40, 11.07it/s]
# Генерація тест-сету:  29%|█████████████████▏                                         | 726/2500 [01:09<02:41, 10.99it/s]
# Генерація тест-сету:  29%|█████████████████▏                                         | 728/2500 [01:09<02:35, 11.38it/s]
# Генерація тест-сету:  29%|█████████████████▏                                         | 730/2500 [01:09<02:38, 11.15it/s]
# Генерація тест-сету:  29%|█████████████████▎                                         | 732/2500 [01:09<02:47, 10.57it/s]
# Генерація тест-сету:  29%|█████████████████▎                                         | 734/2500 [01:09<02:53, 10.17it/s]
# Генерація тест-сету:  29%|█████████████████▎                                         | 736/2500 [01:10<02:59,  9.84it/s]
# Генерація тест-сету:  30%|█████████████████▍                                         | 738/2500 [01:10<02:52, 10.21it/s]
# Генерація тест-сету:  30%|█████████████████▍                                         | 740/2500 [01:10<02:58,  9.89it/s]
# Генерація тест-сету:  30%|█████████████████▌                                         | 742/2500 [01:10<02:39, 11.00it/s]
# Генерація тест-сету:  30%|█████████████████▌                                         | 744/2500 [01:10<02:46, 10.52it/s]
# Генерація тест-сету:  30%|█████████████████▌                                         | 746/2500 [01:11<02:46, 10.56it/s]
# Генерація тест-сету:  30%|█████████████████▋                                         | 748/2500 [01:11<03:02,  9.58it/s]
# Генерація тест-сету:  30%|█████████████████▋                                         | 750/2500 [01:11<03:11,  9.16it/s]
# Генерація тест-сету:  30%|█████████████████▋                                         | 751/2500 [01:11<03:09,  9.23it/s]
# Генерація тест-сету:  30%|█████████████████▊                                         | 753/2500 [01:11<03:07,  9.33it/s]
# Генерація тест-сету:  30%|█████████████████▊                                         | 754/2500 [01:11<03:08,  9.26it/s]
# Генерація тест-сету:  30%|█████████████████▊                                         | 756/2500 [01:12<03:04,  9.47it/s]
# Генерація тест-сету:  30%|█████████████████▉                                         | 758/2500 [01:12<03:02,  9.56it/s]
# ...
# Генерація тест-сету:  91%|████████████████████████████████████████████████████▋     | 2271/2500 [03:45<00:26,  8.55it/s]
# Генерація тест-сету:  91%|████████████████████████████████████████████████████▋     | 2273/2500 [03:45<00:23,  9.58it/s]
# Генерація тест-сету:  91%|████████████████████████████████████████████████████▊     | 2275/2500 [03:45<00:19, 11.27it/s]
# Генерація тест-сету:  91%|████████████████████████████████████████████████████▊     | 2277/2500 [03:45<00:18, 12.02it/s]
# Генерація тест-сету:  91%|████████████████████████████████████████████████████▊     | 2279/2500 [03:46<00:20, 11.05it/s]
# Генерація тест-сету:  91%|████████████████████████████████████████████████████▉     | 2281/2500 [03:46<00:28,  7.59it/s]
# Генерація тест-сету:  91%|████████████████████████████████████████████████████▉     | 2282/2500 [03:46<00:29,  7.47it/s]
# Генерація тест-сету:  91%|████████████████████████████████████████████████████▉     | 2283/2500 [03:46<00:29,  7.46it/s]
# Генерація тест-сету:  91%|████████████████████████████████████████████████████▉     | 2284/2500 [03:47<00:28,  7.67it/s]
# Генерація тест-сету:  91%|█████████████████████████████████████████████████████     | 2285/2500 [03:47<00:26,  8.11it/s]
# Генерація тест-сету:  91%|█████████████████████████████████████████████████████     | 2287/2500 [03:47<00:24,  8.57it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████     | 2289/2500 [03:47<00:24,  8.77it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▏    | 2290/2500 [03:47<00:23,  8.91it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▏    | 2292/2500 [03:47<00:22,  9.24it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▏    | 2293/2500 [03:47<00:22,  9.04it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▏    | 2295/2500 [03:48<00:21,  9.64it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▎    | 2297/2500 [03:48<00:20,  9.79it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▎    | 2299/2500 [03:48<00:18, 10.64it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▍    | 2301/2500 [03:48<00:18, 10.96it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▍    | 2303/2500 [03:48<00:18, 10.83it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▍    | 2305/2500 [03:49<00:18, 10.78it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▌    | 2307/2500 [03:49<00:18, 10.51it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▌    | 2309/2500 [03:49<00:17, 10.84it/s]
# Генерація тест-сету:  92%|█████████████████████████████████████████████████████▌    | 2311/2500 [03:49<00:17, 10.51it/s]
# Генерація тест-сету:  93%|█████████████████████████████████████████████████████▋    | 2313/2500 [03:49<00:17, 10.45it/s]
# Генерація тест-сету:  93%|█████████████████████████████████████████████████████▋    | 2315/2500 [03:50<00:17, 10.34it/s]
# Генерація тест-сету:  93%|█████████████████████████████████████████████████████▊    | 2317/2500 [03:50<00:17, 10.21it/s]
# Генерація тест-сету:  93%|█████████████████████████████████████████████████████▊    | 2319/2500 [03:50<00:17, 10.41it/s]
# Генерація тест-сету:  93%|█████████████████████████████████████████████████████▊    | 2321/2500 [03:50<00:16, 11.07it/s]
# Генерація тест-сету:  93%|█████████████████████████████████████████████████████▉    | 2323/2500 [03:50<00:15, 11.69it/s]
# Генерація тест-сету:  93%|█████████████████████████████████████████████████████▉    | 2325/2500 [03:50<00:15, 11.46it/s]
# Генерація тест-сету:  93%|█████████████████████████████████████████████████████▉    | 2327/2500 [03:51<00:14, 11.59it/s]
# Генерація тест-сету:  93%|██████████████████████████████████████████████████████    | 2329/2500 [03:51<00:15, 11.29it/s]
# Генерація тест-сету:  93%|██████████████████████████████████████████████████████    | 2331/2500 [03:51<00:14, 11.86it/s]
# Генерація тест-сету:  93%|██████████████████████████████████████████████████████▏   | 2333/2500 [03:51<00:14, 11.82it/s]
# Генерація тест-сету:  93%|██████████████████████████████████████████████████████▏   | 2335/2500 [03:51<00:15, 10.90it/s]
# Генерація тест-сету:  93%|██████████████████████████████████████████████████████▏   | 2337/2500 [03:51<00:14, 10.99it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▎   | 2339/2500 [03:52<00:13, 11.57it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▎   | 2341/2500 [03:52<00:15, 10.59it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▎   | 2343/2500 [03:52<00:14, 10.60it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▍   | 2345/2500 [03:52<00:14, 11.02it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▍   | 2347/2500 [03:52<00:13, 11.19it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▍   | 2349/2500 [03:53<00:14, 10.57it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▌   | 2351/2500 [03:53<00:14, 10.51it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▌   | 2353/2500 [03:53<00:14, 10.40it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▋   | 2355/2500 [03:53<00:14, 10.07it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▋   | 2357/2500 [03:53<00:15,  9.51it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▋   | 2359/2500 [03:54<00:14,  9.79it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▊   | 2360/2500 [03:54<00:14,  9.54it/s]
# Генерація тест-сету:  94%|██████████████████████████████████████████████████████▊   | 2362/2500 [03:54<00:14,  9.68it/s]
# Генерація тест-сету:  95%|██████████████████████████████████████████████████████▊   | 2363/2500 [03:54<00:14,  9.42it/s]
# Генерація тест-сету:  95%|██████████████████████████████████████████████████████▊   | 2364/2500 [03:54<00:15,  9.06it/s]
# Генерація тест-сету:  95%|██████████████████████████████████████████████████████▉   | 2366/2500 [03:54<00:13,  9.86it/s]
# Генерація тест-сету:  95%|██████████████████████████████████████████████████████▉   | 2367/2500 [03:54<00:14,  9.18it/s]
# Генерація тест-сету:  95%|██████████████████████████████████████████████████████▉   | 2368/2500 [03:55<00:14,  9.33it/s]
# Генерація тест-сету:  95%|██████████████████████████████████████████████████████▉   | 2370/2500 [03:55<00:13,  9.92it/s]
# Генерація тест-сету:  95%|███████████████████████████████████████████████████████   | 2372/2500 [03:55<00:12, 10.02it/s]
# Генерація тест-сету:  95%|███████████████████████████████████████████████████████   | 2373/2500 [03:55<00:13,  9.72it/s]
# Генерація тест-сету:  95%|███████████████████████████████████████████████████████   | 2375/2500 [03:55<00:11, 10.73it/s]
# Генерація тест-сету:  95%|███████████████████████████████████████████████████████▏  | 2377/2500 [03:55<00:10, 12.04it/s]
# Генерація тест-сету:  95%|███████████████████████████████████████████████████████▏  | 2379/2500 [03:56<00:09, 12.60it/s]
# Генерація тест-сету:  95%|███████████████████████████████████████████████████████▏  | 2381/2500 [03:56<00:10, 11.90it/s]
# Генерація тест-сету:  95%|███████████████████████████████████████████████████████▎  | 2383/2500 [03:56<00:10, 11.15it/s]
# Генерація тест-сету:  95%|███████████████████████████████████████████████████████▎  | 2385/2500 [03:56<00:10, 11.17it/s]
# Генерація тест-сету:  95%|███████████████████████████████████████████████████████▍  | 2387/2500 [03:56<00:09, 12.05it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▍  | 2389/2500 [03:56<00:09, 11.44it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▍  | 2391/2500 [03:57<00:09, 11.30it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▌  | 2393/2500 [03:57<00:09, 10.78it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▌  | 2395/2500 [03:57<00:10,  9.75it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▌  | 2397/2500 [03:57<00:11,  8.68it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▋  | 2399/2500 [03:58<00:10,  9.25it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▋  | 2401/2500 [03:58<00:10,  9.19it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▋  | 2403/2500 [03:58<00:10,  8.90it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▊  | 2404/2500 [03:58<00:11,  8.33it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▊  | 2406/2500 [03:58<00:11,  8.32it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▊  | 2407/2500 [03:59<00:11,  8.31it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▊  | 2408/2500 [03:59<00:11,  7.87it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▉  | 2410/2500 [03:59<00:13,  6.83it/s]
# Генерація тест-сету:  96%|███████████████████████████████████████████████████████▉  | 2412/2500 [03:59<00:11,  7.76it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████  | 2414/2500 [03:59<00:09,  8.84it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████  | 2416/2500 [04:00<00:08,  9.74it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████  | 2418/2500 [04:00<00:07, 10.62it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▏ | 2420/2500 [04:00<00:07, 11.14it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▏ | 2422/2500 [04:00<00:06, 11.51it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▏ | 2424/2500 [04:00<00:06, 11.96it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▎ | 2426/2500 [04:00<00:06, 11.34it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▎ | 2428/2500 [04:01<00:06, 10.85it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▍ | 2430/2500 [04:01<00:06, 10.68it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▍ | 2432/2500 [04:01<00:06, 10.43it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▍ | 2434/2500 [04:01<00:06, 10.28it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▌ | 2436/2500 [04:01<00:06,  9.88it/s]
# Генерація тест-сету:  97%|████████████████████████████████████████████████████████▌ | 2437/2500 [04:02<00:06,  9.55it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▌ | 2439/2500 [04:02<00:05, 10.94it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▋ | 2441/2500 [04:02<00:05, 10.53it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▋ | 2443/2500 [04:02<00:05, 10.31it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▋ | 2445/2500 [04:02<00:05,  9.82it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▊ | 2447/2500 [04:02<00:05,  9.78it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▊ | 2449/2500 [04:03<00:05, 10.14it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▊ | 2451/2500 [04:03<00:06,  7.46it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▉ | 2453/2500 [04:03<00:05,  8.28it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▉ | 2454/2500 [04:03<00:05,  8.14it/s]
# Генерація тест-сету:  98%|████████████████████████████████████████████████████████▉ | 2455/2500 [04:04<00:05,  8.33it/s]
# Генерація тест-сету:  98%|█████████████████████████████████████████████████████████ | 2457/2500 [04:04<00:04,  8.99it/s]
# Генерація тест-сету:  98%|█████████████████████████████████████████████████████████ | 2458/2500 [04:04<00:05,  8.26it/s]
# Генерація тест-сету:  98%|█████████████████████████████████████████████████████████ | 2459/2500 [04:04<00:04,  8.38it/s]
# Генерація тест-сету:  98%|█████████████████████████████████████████████████████████ | 2460/2500 [04:04<00:04,  8.47it/s]
# Генерація тест-сету:  98%|█████████████████████████████████████████████████████████ | 2462/2500 [04:04<00:04,  8.95it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▏| 2463/2500 [04:04<00:04,  8.72it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▏| 2464/2500 [04:05<00:04,  8.79it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▏| 2466/2500 [04:05<00:03, 10.01it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▏| 2467/2500 [04:05<00:03,  8.89it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▎| 2468/2500 [04:05<00:03,  8.72it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▎| 2470/2500 [04:05<00:03,  9.75it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▎| 2472/2500 [04:05<00:02,  9.98it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▎| 2473/2500 [04:05<00:02,  9.56it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▍| 2474/2500 [04:06<00:02,  9.53it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▍| 2475/2500 [04:06<00:02,  9.08it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▍| 2476/2500 [04:06<00:02,  8.74it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▍| 2478/2500 [04:06<00:02,  9.19it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▌| 2480/2500 [04:06<00:02,  9.96it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▌| 2482/2500 [04:06<00:01, 10.33it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▋| 2484/2500 [04:07<00:01, 10.54it/s]
# Генерація тест-сету:  99%|█████████████████████████████████████████████████████████▋| 2486/2500 [04:07<00:01, 10.85it/s]
# Генерація тест-сету: 100%|█████████████████████████████████████████████████████████▋| 2488/2500 [04:07<00:01, 11.37it/s]
# Генерація тест-сету: 100%|█████████████████████████████████████████████████████████▊| 2490/2500 [04:07<00:00, 11.62it/s]
# Генерація тест-сету: 100%|█████████████████████████████████████████████████████████▊| 2492/2500 [04:07<00:00, 10.51it/s]
# Генерація тест-сету: 100%|█████████████████████████████████████████████████████████▊| 2494/2500 [04:07<00:00, 10.30it/s]
# Генерація тест-сету: 100%|█████████████████████████████████████████████████████████▉| 2496/2500 [04:08<00:00,  9.75it/s]
# Генерація тест-сету: 100%|█████████████████████████████████████████████████████████▉| 2497/2500 [04:08<00:00,  9.45it/s]
# Генерація тест-сету: 100%|█████████████████████████████████████████████████████████▉| 2498/2500 [04:08<00:00,  9.13it/s]
# Генерація тест-сету: 100%|██████████████████████████████████████████████████████████| 2500/2500 [04:08<00:00, 10.05it/s]
# --- ✅ Створено 5000 тестових зразків у learning/final_test_set ---
