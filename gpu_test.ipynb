# %%
import tensorflow as tf

# Ця команда покаже всі фізичні пристрої, які бачить TensorFlow
gpu_devices = tf.config.list_physical_devices('GPU')

if gpu_devices:
    print(f"🎉 Вітаю! TensorFlow бачить вашу GPU:")
    for device in gpu_devices:
        print(f"   - {device}")
else:
    print("😥 TensorFlow не бачить вашу GPU. Навчання буде на CPU.")
    print("   Перевірте, чи встановлені CUDA та cuDNN.")
# Out:
# 2025-11-12 14:11:18.726249: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-12 14:11:19.280842: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-12 14:11:21.527963: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 🎉 Вітаю! TensorFlow бачить вашу GPU:
#    - PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.python.platform import build_info as bi
import json; print(json.dumps(bi.build_info, indent=2))
# Out:
# {
#   "cpu_compiler": "clang 18",
#   "cuda_compute_capabilities": [
#     "sm_60",
#     "sm_70",
#     "sm_80",
#     "sm_89",
#     "compute_90"
#   ],
#   "cuda_version": "12.5.1",
#   "cudnn_version": "9",
#   "is_cuda_build": true,
#   "is_rocm_build": false,
#   "is_tensorrt_build": false
# }

# %%
import os, sys, shutil
from pathlib import Path

venv = Path(sys.prefix)
src = venv / "Lib" / "site-packages" / "nvidia"
dst = venv / "Library" / "bin"
dst.mkdir(parents=True, exist_ok=True)

for lib in src.rglob("*.dll"):
    shutil.copy(lib, dst)
print("✅ CUDA DLLs скопійовано в:", dst)
# Out:
# ✅ CUDA DLLs скопійовано в: /home/yesman/tfvenv/Library/bin

# %%
# !pip install nvidia-cudnn-cu12 nvidia-cublas-cu12 nvidia-cuda-runtime-cu12
# Out:
# Requirement already satisfied: nvidia-cudnn-cu12 in /home/yesman/tfvenv/lib/python3.12/site-packages (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12 in /home/yesman/tfvenv/lib/python3.12/site-packages (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12 in /home/yesman/tfvenv/lib/python3.12/site-packages (12.8.90)

# %%
# !pip uninstall tensorflow -y
# Out:
# Found existing installation: tensorflow 2.20.0
# Uninstalling tensorflow-2.20.0:
#   Successfully uninstalled tensorflow-2.20.0

# %%
# !pip install tensorflow[and-cuda]
# Out:
# Collecting tensorflow[and-cuda]
#   Using cached tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.4.0)
# Requirement already satisfied: packaging in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.32.5)
# Requirement already satisfied: setuptools in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.2.6)
# Requirement already satisfied: h5py>=3.11.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (0.5.3)
# Requirement already satisfied: nvidia-cublas-cu12<13.0,>=12.5.3.2 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12<13.0,>=12.5.82 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12<13.0,>=12.5.82 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.9.86)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12<13.0,>=12.5.82 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12<13.0,>=12.5.82 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.3.0.75 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (9.10.2.21)
# Requirement already satisfied: nvidia-cufft-cu12<12.0,>=11.2.3.61 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12<11.0,>=10.3.6.82 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12<12.0,>=11.6.3.83 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12<13.0,>=12.5.1.3 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.5.8.93)
# Requirement already satisfied: nvidia-nccl-cu12<3.0,>=2.25.1 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.27.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12<13.0,>=12.5.82 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.93)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/yesman/tfvenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/yesman/tfvenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/yesman/tfvenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yesman/tfvenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]) (3.9)
# Requirement already satisfied: pillow in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/yesman/tfvenv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow[and-cuda]) (0.45.1)
# Requirement already satisfied: rich in /home/yesman/tfvenv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow[and-cuda]) (14.2.0)
# Requirement already satisfied: namex in /home/yesman/tfvenv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow[and-cuda]) (0.1.0)
# Requirement already satisfied: optree in /home/yesman/tfvenv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow[and-cuda]) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/yesman/tfvenv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow[and-cuda]) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow[and-cuda]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/yesman/tfvenv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow[and-cuda]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/yesman/tfvenv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow[and-cuda]) (0.1.2)
# Using cached tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.7 MB)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-2.20.0
